# %% [markdown]
# <a href="https://colab.research.google.com/github/ruu1004/DRDO/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression ,LogisticRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error ,mean_squared_error, median_absolute_error,confusion_matrix,accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC ,SVR
from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings('ignore')

# %%
Data = pd.read_csv('/content/wine dataset.csv')
del Data['Id']
#Data.drop(columns="Id",inplace=True)
#Data.drop('Id',axis=1)

# %%
Data['quality'] = Data['quality']-3
Data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality
# 0         9.4        2
# 1         9.8        2
# 2         9.8        2
# 3         9.8        3
# 4         9.4        2
# ...       ...      ...
# 1138     11.0        3
# 1139      9.5        3
# 1140     10.5        2
# 1141     11.2        3
# 1142     10.2        2
#
# [1143 rows x 12 columns]

# %%
Data.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            6.7              0.58         0.08             1.8      0.097
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
# 5                 13.0                  40.0   0.9978  3.51       0.56
# 6                 15.0                  59.0   0.9964  3.30       0.46
# 7                 15.0                  21.0   0.9946  3.39       0.47
# 8                  9.0                  18.0   0.9968  3.36       0.57
# 9                 15.0                  65.0   0.9959  3.28       0.54
#
#    alcohol  quality
# 0      9.4        2
# 1      9.8        2
# 2      9.8        2
# 3      9.8        3
# 4      9.4        2
# 5      9.4        2
# 6      9.4        2
# 7     10.0        4
# 8      9.5        4
# 9      9.2        2

# %%
Data.head(10).style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_e5d90_row0_col0, #T_e5d90_row4_col0, #T_e5d90_row5_col0 {
#   background-color: #fed8c7;
#   color: #000000;
# }
# #T_e5d90_row0_col1, #T_e5d90_row4_col1 {
#   background-color: #d92523;
#   color: #f1f1f1;
# }
# #T_e5d90_row0_col2, #T_e5d90_row0_col11, #T_e5d90_row1_col2, #T_e5d90_row1_col11, #T_e5d90_row2_col11, #T_e5d90_row3_col1, #T_e5d90_row3_col8, #T_e5d90_row4_col2, #T_e5d90_row4_col11, #T_e5d90_row5_col2, #T_e5d90_row5_col11, #T_e5d90_row6_col9, #T_e5d90_row6_col11, #T_e5d90_row7_col2, #T_e5d90_row7_col3, #T_e5d90_row7_col4, #T_e5d90_row7_col7, #T_e5d90_row8_col5, #T_e5d90_row8_col6, #T_e5d90_row9_col0, #T_e5d90_row9_col10, #T_e5d90_row9_col11 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_e5d90_row0_col3, #T_e5d90_row3_col3, #T_e5d90_row4_col3, #T_e5d90_row8_col1, #T_e5d90_row8_col9, #T_e5d90_row9_col1 {
#   background-color: #fb6b4b;
#   color: #f1f1f1;
# }
# #T_e5d90_row0_col4, #T_e5d90_row4_col4 {
#   background-color: #fca082;
#   color: #000000;
# }
# #T_e5d90_row0_col5, #T_e5d90_row4_col5 {
#   background-color: #fee0d2;
#   color: #000000;
# }
# #T_e5d90_row0_col6, #T_e5d90_row4_col6 {
#   background-color: #fca285;
#   color: #000000;
# }
# #T_e5d90_row0_col7, #T_e5d90_row4_col7, #T_e5d90_row5_col7 {
#   background-color: #840711;
#   color: #f1f1f1;
# }
# #T_e5d90_row0_col8, #T_e5d90_row1_col1, #T_e5d90_row1_col3, #T_e5d90_row1_col4, #T_e5d90_row1_col5, #T_e5d90_row1_col6, #T_e5d90_row1_col9, #T_e5d90_row3_col0, #T_e5d90_row3_col2, #T_e5d90_row3_col7, #T_e5d90_row4_col8, #T_e5d90_row5_col8, #T_e5d90_row7_col10, #T_e5d90_row7_col11, #T_e5d90_row8_col11 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_e5d90_row0_col9, #T_e5d90_row4_col9, #T_e5d90_row5_col9 {
#   background-color: #fb7858;
#   color: #f1f1f1;
# }
# #T_e5d90_row0_col10, #T_e5d90_row4_col10, #T_e5d90_row5_col5, #T_e5d90_row5_col10, #T_e5d90_row6_col10 {
#   background-color: #fcbba1;
#   color: #000000;
# }
# #T_e5d90_row1_col0, #T_e5d90_row2_col0, #T_e5d90_row8_col0, #T_e5d90_row8_col4 {
#   background-color: #fcbda4;
#   color: #000000;
# }
# #T_e5d90_row1_col7, #T_e5d90_row8_col7 {
#   background-color: #e93529;
#   color: #f1f1f1;
# }
# #T_e5d90_row1_col8 {
#   background-color: #fee2d5;
#   color: #000000;
# }
# #T_e5d90_row1_col10, #T_e5d90_row2_col10, #T_e5d90_row3_col10 {
#   background-color: #ca181d;
#   color: #f1f1f1;
# }
# #T_e5d90_row2_col1 {
#   background-color: #bc141a;
#   color: #f1f1f1;
# }
# #T_e5d90_row2_col2 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_e5d90_row2_col3 {
#   background-color: #bf151b;
#   color: #f1f1f1;
# }
# #T_e5d90_row2_col4 {
#   background-color: #b61319;
#   color: #f1f1f1;
# }
# #T_e5d90_row2_col5, #T_e5d90_row6_col5, #T_e5d90_row7_col5, #T_e5d90_row8_col10, #T_e5d90_row9_col5 {
#   background-color: #fc9272;
#   color: #000000;
# }
# #T_e5d90_row2_col6 {
#   background-color: #cf1c1f;
#   color: #f1f1f1;
# }
# #T_e5d90_row2_col7 {
#   background-color: #d82422;
#   color: #f1f1f1;
# }
# #T_e5d90_row2_col8, #T_e5d90_row6_col3 {
#   background-color: #fcaf93;
#   color: #000000;
# }
# #T_e5d90_row2_col9 {
#   background-color: #a81016;
#   color: #f1f1f1;
# }
# #T_e5d90_row3_col4, #T_e5d90_row5_col4 {
#   background-color: #fcaa8d;
#   color: #000000;
# }
# #T_e5d90_row3_col5, #T_e5d90_row3_col11 {
#   background-color: #fb694a;
#   color: #f1f1f1;
# }
# #T_e5d90_row3_col6 {
#   background-color: #aa1016;
#   color: #f1f1f1;
# }
# #T_e5d90_row3_col9 {
#   background-color: #f7593f;
#   color: #f1f1f1;
# }
# #T_e5d90_row5_col1 {
#   background-color: #ec382b;
#   color: #f1f1f1;
# }
# #T_e5d90_row5_col3, #T_e5d90_row9_col3 {
#   background-color: #fc8161;
#   color: #f1f1f1;
# }
# #T_e5d90_row5_col6 {
#   background-color: #fb7b5b;
#   color: #f1f1f1;
# }
# #T_e5d90_row6_col0 {
#   background-color: #fcb69b;
#   color: #000000;
# }
# #T_e5d90_row6_col1 {
#   background-color: #f85d42;
#   color: #f1f1f1;
# }
# #T_e5d90_row6_col2 {
#   background-color: #fee3d7;
#   color: #000000;
# }
# #T_e5d90_row6_col4 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_e5d90_row6_col6 {
#   background-color: #b01217;
#   color: #f1f1f1;
# }
# #T_e5d90_row6_col7 {
#   background-color: #f85f43;
#   color: #f1f1f1;
# }
# #T_e5d90_row6_col8 {
#   background-color: #fc8a6a;
#   color: #f1f1f1;
# }
# #T_e5d90_row7_col0 {
#   background-color: #fedecf;
#   color: #000000;
# }
# #T_e5d90_row7_col1 {
#   background-color: #f03f2e;
#   color: #f1f1f1;
# }
# #T_e5d90_row7_col6 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_e5d90_row7_col8 {
#   background-color: #e53228;
#   color: #f1f1f1;
# }
# #T_e5d90_row7_col9 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_e5d90_row8_col2 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_e5d90_row8_col3, #T_e5d90_row8_col8 {
#   background-color: #f44f39;
#   color: #f1f1f1;
# }
# #T_e5d90_row9_col2 {
#   background-color: #fedbcc;
#   color: #000000;
# }
# #T_e5d90_row9_col4 {
#   background-color: #75030f;
#   color: #f1f1f1;
# }
# #T_e5d90_row9_col6 {
#   background-color: #7a0510;
#   color: #f1f1f1;
# }
# #T_e5d90_row9_col7 {
#   background-color: #fc9070;
#   color: #000000;
# }
# #T_e5d90_row9_col8 {
#   background-color: #fc9d7f;
#   color: #000000;
# }
# #T_e5d90_row9_col9 {
#   background-color: #fc9576;
#   color: #000000;
# }
# </style>
# <table id="T_e5d90" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e5d90_level0_col0" class="col_heading level0 col0" >fixed acidity</th>
#       <th id="T_e5d90_level0_col1" class="col_heading level0 col1" >volatile acidity</th>
#       <th id="T_e5d90_level0_col2" class="col_heading level0 col2" >citric acid</th>
#       <th id="T_e5d90_level0_col3" class="col_heading level0 col3" >residual sugar</th>
#       <th id="T_e5d90_level0_col4" class="col_heading level0 col4" >chlorides</th>
#       <th id="T_e5d90_level0_col5" class="col_heading level0 col5" >free sulfur dioxide</th>
#       <th id="T_e5d90_level0_col6" class="col_heading level0 col6" >total sulfur dioxide</th>
#       <th id="T_e5d90_level0_col7" class="col_heading level0 col7" >density</th>
#       <th id="T_e5d90_level0_col8" class="col_heading level0 col8" >pH</th>
#       <th id="T_e5d90_level0_col9" class="col_heading level0 col9" >sulphates</th>
#       <th id="T_e5d90_level0_col10" class="col_heading level0 col10" >alcohol</th>
#       <th id="T_e5d90_level0_col11" class="col_heading level0 col11" >quality</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e5d90_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e5d90_row0_col0" class="data row0 col0" >7.400000</td>
#       <td id="T_e5d90_row0_col1" class="data row0 col1" >0.700000</td>
#       <td id="T_e5d90_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_e5d90_row0_col3" class="data row0 col3" >1.900000</td>
#       <td id="T_e5d90_row0_col4" class="data row0 col4" >0.076000</td>
#       <td id="T_e5d90_row0_col5" class="data row0 col5" >11.000000</td>
#       <td id="T_e5d90_row0_col6" class="data row0 col6" >34.000000</td>
#       <td id="T_e5d90_row0_col7" class="data row0 col7" >0.997800</td>
#       <td id="T_e5d90_row0_col8" class="data row0 col8" >3.510000</td>
#       <td id="T_e5d90_row0_col9" class="data row0 col9" >0.560000</td>
#       <td id="T_e5d90_row0_col10" class="data row0 col10" >9.400000</td>
#       <td id="T_e5d90_row0_col11" class="data row0 col11" >2</td>
#     </tr>
#     <tr>
#       <th id="T_e5d90_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e5d90_row1_col0" class="data row1 col0" >7.800000</td>
#       <td id="T_e5d90_row1_col1" class="data row1 col1" >0.880000</td>
#       <td id="T_e5d90_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_e5d90_row1_col3" class="data row1 col3" >2.600000</td>
#       <td id="T_e5d90_row1_col4" class="data row1 col4" >0.098000</td>
#       <td id="T_e5d90_row1_col5" class="data row1 col5" >25.000000</td>
#       <td id="T_e5d90_row1_col6" class="data row1 col6" >67.000000</td>
#       <td id="T_e5d90_row1_col7" class="data row1 col7" >0.996800</td>
#       <td id="T_e5d90_row1_col8" class="data row1 col8" >3.200000</td>
#       <td id="T_e5d90_row1_col9" class="data row1 col9" >0.680000</td>
#       <td id="T_e5d90_row1_col10" class="data row1 col10" >9.800000</td>
#       <td id="T_e5d90_ro

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 107.3 KB

# %%
Data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
Data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             21.000000     0.995570
# 50%       0.079000            13.000000             37.000000     0.996680
# 75%       0.090000            21.000000             61.000000     0.997845
# max       0.611000            68.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1143.000000  1143.000000  1143.000000  1143.000000
# mean      3.311015     0.657708    10.442111     2.657043
# std       0.156664     0.170399     1.082196     0.805824
# min       2.740000     0.330000     8.400000     0.000000
# 25%       3.205000     0.550000     9.500000     2.000000
# 50%       3.310000     0.620000    10.200000     3.000000
# 75%       3.400000     0.730000    11.100000     3.000000
# max       4.010000     2.000000    14.900000     5.000000

# %%
Data.describe().T.style.background_gradient(cmap = 'Blues')
# Out:
# <style type="text/css">
# #T_4063d_row0_col0, #T_4063d_row1_col0, #T_4063d_row1_col7, #T_4063d_row2_col0, #T_4063d_row2_col3, #T_4063d_row2_col4, #T_4063d_row2_col7, #T_4063d_row3_col0, #T_4063d_row4_col0, #T_4063d_row4_col1, #T_4063d_row4_col2, #T_4063d_row4_col3, #T_4063d_row4_col4, #T_4063d_row4_col5, #T_4063d_row4_col6, #T_4063d_row4_col7, #T_4063d_row5_col0, #T_4063d_row6_col0, #T_4063d_row7_col0, #T_4063d_row7_col2, #T_4063d_row7_col7, #T_4063d_row8_col0, #T_4063d_row9_col0, #T_4063d_row10_col0, #T_4063d_row11_col0, #T_4063d_row11_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_4063d_row0_col1 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_4063d_row0_col2, #T_4063d_row0_col7, #T_4063d_row3_col1, #T_4063d_row3_col7, #T_4063d_row8_col6 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_4063d_row0_col3 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_4063d_row0_col4 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_4063d_row0_col5 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_4063d_row0_col6 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_4063d_row1_col1, #T_4063d_row1_col6, #T_4063d_row9_col6 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_4063d_row1_col2, #T_4063d_row2_col1, #T_4063d_row2_col2, #T_4063d_row2_col5, #T_4063d_row2_col6, #T_4063d_row8_col2, #T_4063d_row9_col2, #T_4063d_row9_col7 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_4063d_row1_col3, #T_4063d_row1_col4, #T_4063d_row1_col5, #T_4063d_row7_col6, #T_4063d_row8_col7, #T_4063d_row9_col1, #T_4063d_row9_col5, #T_4063d_row11_col7 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_4063d_row3_col2, #T_4063d_row3_col6, #T_4063d_row9_col3 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_4063d_row3_col3 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_4063d_row3_col4, #T_4063d_row8_col5 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_4063d_row3_col5, #T_4063d_row11_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_4063d_row5_col1 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_4063d_row5_col2 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_4063d_row5_col3, #T_4063d_row7_col3 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_4063d_row5_col4 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_4063d_row5_col5 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_4063d_row5_col6 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_4063d_row5_col7 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_4063d_row6_col1, #T_4063d_row6_col2, #T_4063d_row6_col4, #T_4063d_row6_col5, #T_4063d_row6_col6, #T_4063d_row6_col7, #T_4063d_row10_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_4063d_row6_col3 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_4063d_row7_col1, #T_4063d_row9_col4 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_4063d_row7_col4, #T_4063d_row10_col7, #T_4063d_row11_col6 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_4063d_row7_col5, #T_4063d_row11_col2 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_4063d_row8_col1 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_4063d_row8_col3 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_4063d_row8_col4 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_4063d_row10_col1 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_4063d_row10_col2 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_4063d_row10_col4 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_4063d_row10_col5 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_4063d_row10_col6 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_4063d_row11_col4 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_4063d_row11_col5 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# </style>
# <table id="T_4063d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4063d_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_4063d_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_4063d_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_4063d_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_4063d_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_4063d_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_4063d_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_4063d_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4063d_level0_row0" class="row_heading level0 row0" >fixed acidity</th>
#       <td id="T_4063d_row0_col0" class="data row0 col0" >1143.000000</td>
#       <td id="T_4063d_row0_col1" class="data row0 col1" >8.311111</td>
#       <td id="T_4063d_row0_col2" class="data row0 col2" >1.747595</td>
#       <td id="T_4063d_row0_col3" class="data row0 col3" >4.600000</td>
#       <td id="T_4063d_row0_col4" class="data row0 col4" >7.100000</td>
#       <td id="T_4063d_row0_col5" class="data row0 col5" >7.900000</td>
#       <td id="T_4063d_row0_col6" class="data row0 col6" >9.100000</td>
#       <td id="T_4063d_row0_col7" class="data row0 col7" >15.900000</td>
#     </tr>
#     <tr>
#       <th id="T_4063d_level0_row1" class="row_heading level0 row1" >volatile acidity</th>
#       <td id="T_4063d_row1_col0" class="data row1 col0" >1143.000000</td>
#       <td id="T_4063d_row1_col1" class="data row1 col1" >0.531339</td>
#       <td id="T_4063d_row1_col2" class="data row1 col2" >0.179633</td>
#       <td id="T_4063d_row1_col3" class="data row1 col3" >0.120000</td>
#       <td id="T_4063d_row1_col4" class="data row1 col4" >0.392500</td>
#       <td id="T_4063d_row1_col5" class="data row1 col5" >0.520000</td>
#       <td id="T_4063d_row1_col6" class="data row1 col6" >0.640000</td>
#       <td id="T_4063d_row1_col7" class="data row1 col7" >1.580000</td>
#     </tr>
#     <tr>
#       <th id="T_4063d_level0_row2" class="row_heading level0 row2" >citric acid</th>
#       <td id="T_4063d_row2_col0" class="data row2 col0" >1143.000000</td>
#       <td id="T_4063d_row2_col1" class="data row2 col1" >0.268364</td>
#       <td id="T_4063d_row2_col2" class="data row2 col2" >0.196686</td>
#       <td id="T_4063d_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_4063d_row2_col4" class="data row2 col4" >0.090000</td>
#       <td id="T_4063d_row2_col5" class="data row2 col5" >0.250000</td>
#       <td id="T_4063d_row2_col6" class="data row2 col6" >0.420000</td>
#       <td id="T_4063d_row2_col7" class="data row2 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4063d_level0_row3" class="row_heading level0 row3" >residual sugar</th>
#       <td id="T_4063d_row3_col0" class="data row3 col0" >1143.000000</td>
#       <td id="T_4063d_row3_col1" class="data row3 col1" >2.532152</td>
#       <td id="T_4063d_row3_col2" class="data row3 col2" >1.355917</td>
#       <td id="T_4063d_row3_col3" class="data row3 col3" >0.900000</td>
#       <td id="T_4063d_row3_col4" class="data row3 col4" >1.900000</td>
#       <td id="T_4063d_row3_col5" class="data row3 col5" >2.200000</td>
#       <td id="T_4063d_row3_col6" class="data row3 col6" >2.600000</td>
#       <td id="T_4063d_row3_col7" class="data row3 col7" >15.500000</td>
#     </tr>
#     <tr>
#       <th id="T_4063d_level0_row4" class="row_heading level0 row4" >chlorides</th>
#       <td id="T_4063d_row4_col0" class="data row4 col0" >1143.000000</td>
#       <td id="T_4063d_row4_col1" class="data row4 col1" >0.086933</td>
#       <td id="T_4063d_row4_col2" class="data row4 col2" >0.047267</td>
#       <td id="T_4063d_row4_col3" class="data row4 col3" >0.012000</td>
#       <td id="T_4063d_row4_col4" class="data row4 col4" >0.070000</td>
#       <td id="T_4063d_row4_col5" class="data row4 col5" >0.079000</td>
#       <td id="T_4063d_row4_col6" class="data row4 col6" >0.090000</td>
#       <td id="T_4063d_row4_col7" class="data row4 col7" >0.611000</td>
#     </tr>
#     <tr>
#       <th id="T_4063d_level0_row5" class="row_heading level0 row5" >free sulfur dioxi

# %%
Data.mean()
# Out:
# fixed acidity            8.311111
# volatile acidity         0.531339
# citric acid              0.268364
# residual sugar           2.532152
# chlorides                0.086933
# free sulfur dioxide     15.615486
# total sulfur dioxide    45.914698
# density                  0.996730
# pH                       3.311015
# sulphates                0.657708
# alcohol                 10.442111
# quality                  2.657043
# dtype: float64

# %%
Data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
Data.duplicated().sum()
# Out:
# 125

# %%
Data.drop_duplicates(inplace = True)

# %%
Data.duplicated().sum()
# Out:
# 0

# %%
Data['quality'].value_counts()
# Out:
# 2    433
# 3    409
# 4    122
# 1     33
# 5     15
# 0      6
# Name: quality, dtype: int64

# %%
plt.figure(figsize = (12, 8))
Data.plot()
plt.show()

# %%
Data.hist(bins=20, figsize=(10, 10))
plt.show()

# %%
plt.bar(Data['quality'], Data['alcohol'])
plt.xlabel('quality')
plt.ylabel('alcohol')
plt.show()

# %%
plt.figure(figsize=(12, 5))
sns.boxplot(data=Data[Data.columns[4:8]])
plt.show()

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(Data.corr(), cbar=True, square=True, fmt='.2f', annot=True, cmap='rainbow')

plt.show()

# %%
plt.figure(figsize=(12, 12))
sns.heatmap(Data.corr() > 0.6, cbar=False, square=True, fmt='.2f', annot=True, annot_kws={'size':10}, cmap='Greens')
plt.show()

# %%
X = Data.drop(columns="quality")
y = Data["quality"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
norm = MinMaxScaler()
x_train = norm.fit_transform(X_train)
x_test = norm.fit_transform(X_test)

print("X Train : ", X_train.shape)
print("X Test  : ", X_test.shape)
print("Y Train : ", y_train.shape)
print("Y Test  : ", y_test.shape)
# Out:
# X Train :  (814, 11)
# X Test  :  (204, 11)
# Y Train :  (814,)
# Y Test  :  (204,)

# %%
Lo_model=LogisticRegression(solver='liblinear')

Lo_model.fit(X_train,y_train)

print("Score the X-train with Y-train is : ", Lo_model.score(X_train,y_train))
print("Score the X-test  with Y-test  is : ", Lo_model.score(X_test,y_test))

y_pred_Lo=Lo_model.predict(X_test)

print( " Model Evaluation Logistic R : mean absolute error is ", mean_absolute_error(y_test,y_pred_Lo))
print(" Model Evaluation Logistic R : mean squared  error is " , mean_squared_error(y_test,y_pred_Lo))
print(" Model Evaluation Logistic R : median absolute error is " ,median_absolute_error(y_test,y_pred_Lo))

print(" Model Evaluation Logistic R : accuracy score " , accuracy_score(y_test,y_pred_Lo))
# Out:
# Score the X-train with Y-train is :  0.5786240786240786
# Score the X-test  with Y-test  is :  0.5980392156862745
#  Model Evaluation Logistic R : mean absolute error is  0.46078431372549017
#  Model Evaluation Logistic R : mean squared  error is  0.5784313725490197
#  Model Evaluation Logistic R : median absolute error is  0.0
#  Model Evaluation Logistic R : accuracy score  0.5980392156862745

# %%
Tree_model=DecisionTreeClassifier(max_depth=50)
Tree_model.fit(X_train,y_train)

print("Score the X-train with Y-train is : ", Tree_model.score(X_train,y_train))
print("Score the X-test  with Y-test  is : ", Tree_model.score(X_test,y_test))
# Out:
# Score the X-train with Y-train is :  1.0
# Score the X-test  with Y-test  is :  0.5294117647058824

# %%
print("The Important columns \n",Tree_model.feature_importances_)
# Out:
# The Important columns
#  [0.04882194 0.13970155 0.07065932 0.07946159 0.08150112 0.06389756
#  0.08761812 0.03430186 0.10685911 0.10386824 0.1833096 ]

# %%
Data.head(0)
# Out:
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality]
# Index: []

# %%
print("The classes ",Tree_model.classes_)

y_pred_T =Tree_model.predict(X_test)

print(" Model Evaluation Decision Tree : accuracy score " , accuracy_score(y_test,y_pred_T))
# Out:
# The classes  [0 1 2 3 4 5]
#  Model Evaluation Decision Tree : accuracy score  0.5294117647058824

# %%
svc_model=SVC(C=50,kernel="rbf")

svc_model.fit(X_train,y_train)

y_pred_svc =svc_model.predict(X_test)

print("Score the X-train with Y-train is : ", svc_model.score(X_train,y_train))
print("Score the X-test  with Y-test  is : ", svc_model.score(X_test,y_test))
print(" Model Evaluation Decision Tree : accuracy score " , accuracy_score(y_test,y_pred_svc))
# Out:
# Score the X-train with Y-train is :  0.585995085995086
# Score the X-test  with Y-test  is :  0.5980392156862745
#  Model Evaluation Decision Tree : accuracy score  0.5980392156862745

# %%
svr_model=SVR(degree=1,coef0=1, tol=0.001, C=1.5,epsilon=0.001)

svr_model.fit(X_train,y_train)

y_pred_svr =svc_model.predict(X_test)

print("Score the X-train with Y-train is : ", svr_model.score(X_train,y_train))
print("Score the X-test  with Y-test  is : ", svr_model.score(X_test,y_test))
print(" Model Evaluation Decision Tree : accuracy score " , accuracy_score(y_test,y_pred_svr))
# Out:
# Score the X-train with Y-train is :  0.12962892216565103
# Score the X-test  with Y-test  is :  0.21472750540513974
#  Model Evaluation Decision Tree : accuracy score  0.5980392156862745

# %%
K_model = KNeighborsClassifier(n_neighbors = 8)
K_model.fit(X_train, y_train)

y_pred_k = K_model.predict(X_test)

print("Score the X-train with Y-train is : ", K_model.score(X_train,y_train))
print("Score the X-test  with Y-test  is : ", K_model.score(X_test,y_test))
print(" Model Evaluation K Neighbors Classifier : accuracy score " , accuracy_score(y_test,y_pred_k))
# Out:
# Score the X-train with Y-train is :  0.581081081081081
# Score the X-test  with Y-test  is :  0.5686274509803921
#  Model Evaluation K Neighbors Classifier : accuracy score  0.5686274509803921

# %%
#RandomForestClassifier
model = RandomForestClassifier()

# Fit the model to the training data
model.fit(X_train, y_train)

# Predict using the model on the test data
pred = model.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, pred)



# Generate confusion matrix
conf_matrix = confusion_matrix(y_test, pred)

# Display the confusion matrix using a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", cbar=False,
            xticklabels=model.classes_, yticklabels=model.classes_)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()

print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.6470588235294118
